# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf

# %%
df1 = pd.read_csv('patients.csv')
df2 = pd.read_csv('allergies.csv', parse_dates=['STOP'])
df_al = df1.merge(df2, left_on = 'Id', right_on = 'PATIENT')
df_al
# Out:
#                                        Id   BIRTHDATE   DEATHDATE  \
# 0    76982e06-f8b8-4509-9ca3-65a99c8650fe  1982-09-01         NaN
# 1    76982e06-f8b8-4509-9ca3-65a99c8650fe  1982-09-01         NaN
# 2    71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2000-11-21  2012-11-21
# 3    71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2000-11-21  2012-11-21
# 4    71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2000-11-21  2012-11-21
# ..                                    ...         ...         ...
# 592  e6ff4bf9-09c2-4976-aa84-cca142207cf8  1998-12-23         NaN
# 593  e6ff4bf9-09c2-4976-aa84-cca142207cf8  1998-12-23         NaN
# 594  e6ff4bf9-09c2-4976-aa84-cca142207cf8  1998-12-23         NaN
# 595  e6ff4bf9-09c2-4976-aa84-cca142207cf8  1998-12-23         NaN
# 596  13b9a676-7cfd-4b7c-bdb6-43ec52b7c919  1914-09-05  1977-03-30
#
#              SSN    DRIVERS    PASSPORT PREFIX        FIRST           LAST  \
# 0    999-21-5604  S99957470  X55072337X    Ms.  Christal240        Brown30
# 1    999-21-5604  S99957470  X55072337X    Ms.  Christal240        Brown30
# 2    999-28-2716        NaN         NaN    NaN  Carmelia328  Konopelski743
# 3    999-28-2716        NaN         NaN    NaN  Carmelia328  Konopelski743
# 4    999-28-2716        NaN         NaN    NaN  Carmelia328  Konopelski743
# ..           ...        ...         ...    ...          ...            ...
# 592  999-91-5603  S99952608  X23816401X    Ms.     Corie618        Howe413
# 593  999-91-5603  S99952608  X23816401X    Ms.     Corie618        Howe413
# 594  999-91-5603  S99952608  X23816401X    Ms.     Corie618        Howe413
# 595  999-91-5603  S99952608  X23816401X    Ms.     Corie618        Howe413
# 596  999-80-8862  S99994941  X29811447X   Mrs.     Karma832       Wolff180
#
#     SUFFIX  ...        LAT        LON HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE  \
# 0      NaN  ...  42.284598 -71.134497           779464.29            11713.81
# 1      NaN  ...  42.284598 -71.134497           779464.29            11713.81
# 2      NaN  ...  42.291986 -71.463724           268920.58             9406.69
# 3      NaN  ...  42.291986 -71.463724           268920.58             9406.69
# 4      NaN  ...  42.291986 -71.463724           268920.58             9406.69
# ..     ...  ...        ...        ...                 ...                 ...
# 592    NaN  ...  42.331294 -71.167223           519562.40             3346.40
# 593    NaN  ...  42.331294 -71.167223           519562.40             3346.40
# 594    NaN  ...  42.331294 -71.167223           519562.40             3346.40
# 595    NaN  ...  42.331294 -71.167223           519562.40             3346.40
# 596    NaN  ...  42.226046 -71.151962          1253149.75            11117.12
#
#           START STOP                               PATIENT  \
# 0    1982-10-25  NaT  76982e06-f8b8-4509-9ca3-65a99c8650fe
# 1    1982-10-25  NaT  76982e06-f8b8-4509-9ca3-65a99c8650fe
# 2    2002-01-25  NaT  71ba0469-f0cc-4177-ac70-ea07cb01c8b8
# 3    2002-01-25  NaT  71ba0469-f0cc-4177-ac70-ea07cb01c8b8
# 4    2002-01-25  NaT  71ba0469-f0cc-4177-ac70-ea07cb01c8b8
# ..          ...  ...                                   ...
# 592  2000-01-03  NaT  e6ff4bf9-09c2-4976-aa84-cca142207cf8
# 593  2000-01-03  NaT  e6ff4bf9-09c2-4976-aa84-cca142207cf8
# 594  2000-01-03  NaT  e6ff4bf9-09c2-4976-aa84-cca142207cf8
# 595  2000-01-03  NaT  e6ff4bf9-09c2-4976-aa84-cca142207cf8
# 596  1915-09-12  NaT  13b9a676-7cfd-4b7c-bdb6-43ec52b7c919
#
#                                 ENCOUNTER       CODE              DESCRIPTION
# 0    b896bf40-8b72-42b7-b205-142ee3a56b55  300916003            Latex allergy
# 1    b896bf40-8b72-42b7-b205-142ee3a56b55  300913006        Shellfish allergy
# 2    7be1a590-4239-4826-9872-031327f3c368  419474003         Allergy to mould
# 3    7be1a590-4239-4826-9872-031327f3c368  232347008  Dander (animal) allergy
# 4    7be1a590-4239-4826-9872-031327f3c368  418689008  Allergy to grass pollen
# ..                                    ...        ...                      ...
# 592  6c760807-a6b7-4af4-8d50-f32325803448  418689008  Allergy to grass pollen
# 593  6c760807-a6b7-4af4-8d50-f32325803448  419263009   Allergy to tree pollen
# 594  6c760807-a6b7-4af4-8d50-f32325803448   91930004          Allergy to eggs
# 595  6c760807-a6b7-4af4-8d50-f32325803448   91935009       Allergy to peanuts
# 596  bbd17366-0801-45ee-8589-0f3eb31c7d0d  419474003         Allergy to mould
#
# [597 rows x 31 columns]

# %%
dt_stop = df_al['STOP'].dropna()
dt_stop = dt_stop.unique()
dt_stop
# Out:
# array(['2014-03-20T00:00:00.000000000', '2018-01-30T00:00:00.000000000',
#        '2019-12-30T00:00:00.000000000', '2010-09-01T00:00:00.000000000',
#        '2013-06-25T00:00:00.000000000', '2013-12-18T00:00:00.000000000',
#        '2015-11-30T00:00:00.000000000', '2019-09-12T00:00:00.000000000',
#        '2019-08-03T00:00:00.000000000', '1993-07-10T00:00:00.000000000',
#        '2010-10-28T00:00:00.000000000', '2020-03-21T00:00:00.000000000',
#        '2011-02-03T00:00:00.000000000', '2018-12-17T00:00:00.000000000',
#        '2018-11-22T00:00:00.000000000', '2019-10-21T00:00:00.000000000',
#        '2017-01-31T00:00:00.000000000', '2016-11-21T00:00:00.000000000',
#        '2018-04-11T00:00:00.000000000', '2019-12-25T00:00:00.000000000',
#        '2011-03-09T00:00:00.000000000', '2014-02-05T00:00:00.000000000',
#        '2015-10-05T00:00:00.000000000', '2016-04-04T00:00:00.000000000',
#        '2015-06-13T00:00:00.000000000', '2018-09-08T00:00:00.000000000',
#        '2019-05-02T00:00:00.000000000', '2016-09-18T00:00:00.000000000',
#        '2016-06-25T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df_al['STOP'] = df_al['STOP'].replace(dt_stop, np.full(len(dt_stop), 1))
df_al['STOP'] = df_al['STOP'].replace({pd.NaT: "0"})
df_al['STOP'] = df_al['STOP'].astype('int32')

# %%
features_column = ['RACE', 'ETHNICITY', 'GENDER', 'DESCRIPTION']
label_column = ['STOP']

# %%
dataset = df_al[features_column + label_column]
dataset['STOP'] = dataset['STOP'].astype('int32')

#reference for numerical categories
categorical_dict = {}

#convert categorical data into numerical data
for feature_name in features_column:
    dataset[feature_name] = dataset[feature_name].astype('category')
    categorical_dict.update({feature_name: dataset[feature_name].cat.categories})
    dataset[feature_name] = dataset[feature_name].astype('category').cat.codes
    
print(categorical_dict)
# Out:
# {'RACE': Index(['asian', 'black', 'native', 'white'], dtype='object'), 'ETHNICITY': Index(['hispanic', 'nonhispanic'], dtype='object'), 'GENDER': Index(['F', 'M'], dtype='object'), 'DESCRIPTION': Index(['Allergy to bee venom', 'Allergy to dairy product', 'Allergy to eggs',
#        'Allergy to fish', 'Allergy to grass pollen', 'Allergy to mould',
#        'Allergy to nut', 'Allergy to peanuts', 'Allergy to soya',
#        'Allergy to tree pollen', 'Allergy to wheat', 'Dander (animal) allergy',
#        'House dust mite allergy', 'Latex allergy', 'Shellfish allergy'],
#       dtype='object')}
# <ipython-input-6-452f4aa08d9e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['STOP'] = dataset['STOP'].astype('int32')
# <ipython-input-6-452f4aa08d9e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[feature_name] = dataset[feature_name].astype('category')
# <ipython-input-6-452f4aa08d9e>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[feature_name] = dataset[feature_name].astype('category').cat.codes

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('STOP')
test_labels = test_features.pop('STOP')

# %%
def build_and_compile_model():
  model = keras.Sequential([
      layers.Dense(len(features_column)),
      layers.Dense(64, activation = 'relu'),
      layers.Dense(1)
  ])

  model.compile(loss = 'mean_absolute_error', metrics = ['accuracy'],
                optimizer = 'adam')
  return model

# %%
model = build_and_compile_model()

# %%
#fit the model
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                            patience=3,
                                            mode='min')
history = model.fit(
    train_features[features_column],
    train_labels,
    validation_split=0.2,
    callbacks=early_stopping,
    verbose=1, epochs=100)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7376 - accuracy: 0.3874 - val_loss: 0.3241 - val_accuracy: 0.8854
# Epoch 2/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3569 - accuracy: 0.8953 - val_loss: 0.2656 - val_accuracy: 0.8854
# Epoch 3/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2423 - accuracy: 0.8953 - val_loss: 0.2143 - val_accuracy: 0.8854
# Epoch 4/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1925 - accuracy: 0.8953 - val_loss: 0.1851 - val_accuracy: 0.8854
# Epoch 5/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.8953 - val_loss: 0.1607 - val_accuracy: 0.8854
# Epoch 6/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1405 - accuracy: 0.8953 - val_loss: 0.1450 - val_accuracy: 0.8854
# Epoch 7/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1305 - accuracy: 0.8953 - val_loss: 0.1368 - val_accuracy: 0.8854
# Epoch 8/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1275 - accuracy: 0.8953 - val_loss: 0.1374 - val_accuracy: 0.8854
# Epoch 9/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1212 - accuracy: 0.8953 - val_loss: 0.1325 - val_accuracy: 0.8854
# Epoch 10/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1171 - accuracy: 0.8953 - val_loss: 0.1246 - val_accuracy: 0.8854
# Epoch 11/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1185 - accuracy: 0.8953 - val_loss: 0.1340 - val_accuracy: 0.8854
# Epoch 12/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1299 - accuracy: 0.8953 - val_loss: 0.1297 - val_accuracy: 0.8854
# Epoch 13/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1250 - accuracy: 0.8953 - val_loss: 0.1301 - val_accuracy: 0.8854

# %%
model.evaluate(test_features[features_column], test_labels)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1262 - accuracy: 0.8908
# [0.12616890668869019, 0.8907563090324402]

# %%
model.save('model_allergies')
# Out:
# INFO:tensorflow:Assets written to: model_allergies\assets

# %%
model.predict(np.array([[0, 1, 1, 3]]))
# Out:
# array([[-0.04066223]], dtype=float32)
